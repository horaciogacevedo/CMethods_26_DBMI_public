# %% [markdown]
# # Lists in Python
#
# ## Table of Contents
# 1. [Lists in Python](#list)
# 2. [Manipulating Lists](#manipulation)
# 3. [Useful Methods for Lists](#methods)
# 4. [Lists and Strings](#listsnstrings)
# 5. [Copying a List](#listcopy)
# 6. [References](#references)
#
# ## Lists in Python <a name="list"></a>
#
# A **list** is an ordered collection of items. It is defined using *square brackets* and items are separated by commas.

# %%
my_list=["a",'b','c']
my_list1=["a",'b','3']
my_list2=["a",'b',3]

# %% [markdown]
# As with strings, the first element of a list is the zeroth element.

# %%
print(my_list[0])
# Out:
# a

# %% [markdown]
# Broken example

# %%
my_prospect_list=['a"]
# Out:
#   Cell In[3], line 1
#     my_prospect_list=['a"]
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Since my first element is a **string**, then we can use some of the methods that we've learned

# %%
print(my_list[0].upper())
# Out:
# A

# %% [markdown]
# ### Manipulating Lists <a name="manipulation"></a>
#
# Lists are **MUTABLE**, which means that we can modify them.

# %%
my_list[0]="c"
print(my_list)
# Out:
# ['c', 'b', 'c']

# %%
cities_ar=['Little Rock','Fayetteville','Fort Smith', 'Springdale', 'Jonesboro','Rogers', 'Conway','North Little Rock','Bentonville','Pine Bluff']

# %% [markdown]
# We can slice parts of the list

# %%
cities_ar[2:]
# Out:
# ['Fort Smith',
#  'Springdale',
#  'Jonesboro',
#  'Rogers',
#  'Conway',
#  'North Little Rock',
#  'Bentonville',
#  'Pine Bluff',
#  'Hot Springs']

# %% [markdown]
# #### Exercise
#
# 1. Let's play with the cities in Arkansas. What is wrong with the following definition of *cities_ar*?

# %% [markdown]
# 2. Once you have corrected, add *Hot Springs* to the list.
#
# 3. Slice the cities between Fort Smith and North Little Rock.

# %%
# Your answers to exercise items 1-3 here
cities_ar.append('Hot Springs')

# %%
print(cities_ar)
# Out:
# ['Little Rock', 'Fayetteville', 'Fort Smith', 'Springdale', 'Jonesboro', 'Rogers', 'Conway', 'North Little Rock', 'Bentonville', 'Pine Bluff', 'Hot Springs', 'Hot Springs']

# %%
cities_ar[3:7]
# Out:
# ['Springdale', 'Jonesboro', 'Rogers', 'Conway']

# %%
cities_ar.count("Hot Springs")
# Out:
# 2

# %% [markdown]
# ### Useful Methods for *Lists* <a name="methods"></a>
#
# Suppose the name of your list is L
#
# | Method | Description |
# |-------|--------|
# | len(L) | length of the list L |
# | L.append(y) | Adds the item y at the end of the list |
# | L.extend(m) | Adds the list m at the end of the list L |
# | L.remove(y) | Removes the item y from the list L |
# | L.pop() | Removes the last item from the list L |
# | L.index(y) | Returns the index position of the leftmost occurence of the item y in list L |
# | x in L | Returns True if item x is in list L |
# | x not in L | Returns True if item x is not in list L |
# | L.sort() | Sorts the list |
# | L.reverse() | Reverses list L |
#
# #### Exercise continuation
#
# 4. What is the length of the *cities_ar*
#
# 5. Add at the beginning of the list *Cabot*
#
# 6. Swap North Little Rock and Conway

# %%
# Your answers to exercise items 4-6 here
len(cities_ar)
lonely_city=["Cabot"]
lonely_city.extend(cities_ar)
lonely_city;
lonely_city.index("Conway")
lonely_city.index("North Little Rock")
# Out:
# 8

# %%
lonely_city[8]="Conway"
lonely_city[7]="North Little Rock"
lonely_city
# Out:
# ['Cabot',
#  'Little Rock',
#  'Fayetteville',
#  'Fort Smith',
#  'Springdale',
#  'Jonesboro',
#  'Rogers',
#  'North Little Rock',
#  'Conway',
#  'Bentonville',
#  'Pine Bluff',
#  'Hot Springs',
#  'Hot Springs']

# %% [markdown]
# ## Lists and Strings <a name="listsnstrings"></a>
#
# We know that lists can consist of strings.

# %%
my_list=['string 1','string 2','string 3']
my_list1=list('string 1')
print(my_list1)
# Out:
# ['s', 't', 'r', 'i', 'n', 'g', ' ', '1']

# %% [markdown]
# ## Copying a List <a name="listcopy"></a>
#
# It seems very intuitive to copy

# %%
covid_variants=['Beta','Gamma','Delta','Alpha']
who_variants=covid_variants
covid_variants,who_variants
# Out:
# (['Beta', 'Gamma', 'Delta', 'Alpha'], ['Beta', 'Gamma', 'Delta', 'Alpha'])

# %% [markdown]
# Let's replace the *Alpha* variant with *Alpha with E484K*
#
# First we locate where the *Alpha* variant is and replace with the new value

# %%
who_variants.index('Alpha') # this line will locate the position of the Alpha
who_variants[who_variants.index('Alpha')]='Alpha with E484K' # this is the replacement
covid_variants,who_variants
# Out:
# (['Beta', 'Gamma', 'Delta', 'Alpha with E484K'],
#  ['Beta', 'Gamma', 'Delta', 'Alpha with E484K'])

# %% [markdown]
# In contrast, we can have the following code

# %%
covid_variants=['Beta','Gamma','Delta','Alpha']
who_variants=covid_variants[:]
who_variants[who_variants.index('Alpha')]='Alpha with E484K'
covid_variants,who_variants
# Out:
# (['Beta', 'Gamma', 'Delta', 'Alpha'],
#  ['Beta', 'Gamma', 'Delta', 'Alpha with E484K'])

# %% [markdown]
# The second chunk of code makes a **deep copy** of the list.

# %% [markdown]
# # In class exercise — Variables, Strings, and Lists

# %% [markdown]
# Add Python code to do the following:
#
# 1. Create variables named `givenName` and `familyName` and assign them values so that they store your given name and family name respectively (hint: these values should be Python strings).
#
# 2. Create a variable named `startYear` and assign it a value so that it stores the year you first became affiliated with UAMS (hint: year numbers like 2021 and 1980 are most natural as ints).
#
# 3. Add a print statement that prints out a message reporting your full name, the year you started at UAMS, and how many years ago that was.
#    As an example, Dr. Bona's submission for this part of the exercise might print out the message: *Jonathan Bona joined UAMS in 2016, which was 5 years ago.*
#
# 4. Add a print statement that prints out the total length of your name.
#
# 5. Create a variable named `courses` and assign it a list of strings that represent the names of the courses you are taking this fall. If you are not taking any courses or don't know yet what courses you'll be taking, just make up at least three examples (Underwater Basketweaving, Informatics Approaches to TV Sitcom Analysis, etc). Just for fun, make sure the course names are not in alphabetical order.
#
# 6. Add a print statement that outputs a message with this list of courses.
#
# 7. Add a print statement that outputs a message with the name of just the first course in the list.
#
# 8. Add a print statement that outputs a message with the name of just the last course in the list.
#
# 9. Add a print statement that outputs a message saying how many courses are in the list.
#
# 10. Add a print statement that outputs the result of calling the Python function `sorted` on your list.
#     For example, if your list is named `courses` (it should be), then you would add the following as a line in your Python file: `print(sorted(courses))`
#
# 11. Add a comment that explains what you think the `sorted` function is doing to your list (hint: try running the above line before reporting what it does).

# %%
# 1-2. Personal info variables
givenName = "Joe"
familyName = "Doe"
startYear = 2009
thisYear= 2026

# %%
# 3. Full name, start year, and years since
# 1-2. Personal info variables
givenName = "Minnie"
familyName = "Mouse"
startYear = 1950
thisYear= 2026

# %%
# 3. Full name, start year, and years since
print(f"{givenName} {familyName} joined UAMS in {startYear}, which was {thisYear-startYear} year ago.")
# Out:
# Minnie Mouse joined UAMS in 1950, which was 76 year ago.

# %%
fullName=givenName + " "+familyName
len(fullName)
# Out:
# 12

# %%
# 4. Length of full name
print()

# 5. Courses list
courses = []

# 6. Print the list of courses
print()

# 7. Print the first course
print()

# 8. Print the last course
print()

# 9. Print how many courses are in the list
print()

# 10. Print the sorted list
print(sorted(courses))

# 11. Comment: what does sorted() do to the list?
# TODO: your explanation here

# %% [markdown]
# ## References <a name="references"></a>
#
# 1. [Python Crashcourse](http://www.amazon.com/Python-Crash-Course-2nd-Edition/dp/1593279280/ref=sr_1_3?dchild=1&keywords=python+crash+course&qid=1626355851&sr=8-3) E. Matthes. Second Edition. No starch press (2019)
# 2. [Rapid GUI Programming with Python and Qt](http://www.amazon.com/Programming-Python-Prentice-Software-Development/dp/0132354187/ref=sr_1_3?crid=3HIAT02B1BFAT&dchild=1&keywords=rapid+gui+programming+with+python+and+qt&qid=1626355927&sprefix=rapid+gui+p%2Caps%2C184&sr=8-3) M. Summerfield. Prentice Hall. (2007)
# 3. [Learning Python](http://www.amazon.com/Learning-Python-5th-Mark-Lutz/dp/1449355730/ref=sr_1_3?dchild=1&keywords=learning+python+lutz&qid=1626356046&sr=8-3) M. Lutz. Fourth Edition. O'Reilly (2009)
