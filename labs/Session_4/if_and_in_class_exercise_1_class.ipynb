# %% [markdown]
# # Session 4
#
# ## Table of Contents
#
# **Part 1: Selection Statements (If)**
# 1. [Selection statements (If)](#if)
# 2. [Introducing if](#introif)
# 3. [Parts of an if/else](#ifelse)
# 4. [Elif - checking more than one condition](#elif)
# 5. [And, or, not](#andornot)
#
# **Part 2: In-class Exercise**
#
# 6. [In-class Exercise](#exercise)
# 7. [Task 1: Who is vaccinated?](#task1)
# 8. [Task 2: Vaccinated or not (if/else)](#task2)

# %% [markdown]
# ## Selection statements (If) <a name="if"></a>
#
# The last basic ingredient we haven't learned yet that is completely essential to expressing an algorithm in a programming language is selection: the ability to have the program choose what to do next based on some condition. You will recall that when we started out last week talking about algorithms before we even got to Python, we were saying things like "If the first number is greater than the second, then... answer NO". Today we will look at how to make choices like this in Python using **if** statements.
#
# ### Introducing if <a name="introif"></a>
#
# Here's an extremely simple example that uses an if statement:

# %%
mynum = 5
if mynum > 4:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# This example is so simple it's almost useless! We know what the value of **mynum** is because we just assigned it. Here's another example:

# %%
mysentence = "this is a sentence."
print(mysentence)
if mysentence[0].islower():
    mysentence = mysentence[0].upper() + mysentence[1:]
# Out:
# this is a sentence.

# %%
print(mysentence)
# Out:
# This is a sentence.

# %% [markdown]
# What does this code do? It capitalizes a sentence if it's not already capitalized. There's no **else** part -- if the sentence is already in the right format we leave it alone.
#
# ### Parts of an if/else <a name="ifelse"></a>
#
# You will notice that, just as with **for** loops, there is an indented structure to our **if** statements.
#
# The condition is the part of an if statement that comes right after the keyword **if**. This will always need to be the sort of thing that could be either True or False:

# %%
print(mynum > 4)
print(mysentence[0].islower())
# Out:
# True
# False

# %% [markdown]
# If the condition is true, then the indented part below the if is executed. We will call this indented part under the if the "body" of the if statement.
# If the condition is not true (false), then the body of the if statement is skipped. If the code includes an *else* part, then the else body is executed.
# To make these more useful, let's combine them with a loop that operates on a list.
#
# Let's say we had a list of lists that are about patients:

# %%
# a list of lists representing patients.
# we will use something better than lists for data like this eventually
# the fields here are: MRN, Birthyear, SSN, Given name, Family name, Zip code
patlist = [[7182, 1989, '999-76-5071', 'Edgar', 'Hermann', 72034],
           [7491, 2018, '999-92-3312', 'Dionna', 'Heathcote', 72411],
           [7052, 2013, '999-80-4418', 'Eleni', 'Gusikowski', 72736],
           [4851, 2011, '999-51-6410', 'Ricardo','Mills', 72046],
           [1744, 1969, '999-72-5953', 'Michelle','Breitenberg', 72472]]

# %% [markdown]
# What if we wanted to know which patients were over 30 and which were under 30 years of age?

# %%
current_year=2026
for p in patlist:
    age = current_year - p[1]
    if age > 30:
        print(f"{p[3]} {p[4]} is over 30")
# Out:
# Edgar Hermann is over 30
# Michelle Breitenberg is over 30

# %% [markdown]
# That version only prints a message if the patient is over 30. We can use else to print an appropriate message either way:

# %%
for p in patlist:
    age = current_year - p[1]
    if age > 30:
        print(f"{p[3]} {p[4]} is over 30")
    else:
        print(f"{p[3]} {p[4]} is under 30")
# Out:
# Edgar Hermann is over 30
# Dionna Heathcote is under 30
# Eleni Gusikowski is under 30
# Ricardo Mills is under 30
# Michelle Breitenberg is over 30

# %% [markdown]
# Note also that we don't strictly need to store the age in a variable. We could get the same result with this code:

# %%
for p in patlist:
    if (current_year - p[1]) > 30:
        print(f"{p[3]} {p[4]} is over 30!")
    else:
        print(f"{p[3]} {p[4]} is under 30!")
# Out:
# Edgar Hermann is over 30!
# Dionna Heathcote is under 30!
# Eleni Gusikowski is under 30!
# Ricardo Mills is under 30!
# Michelle Breitenberg is over 30!

# %% [markdown]
# Of course we don't **need** an if statement to calculate someone's age or compare their age to another number. We only need the if (if/else) when we want to do something different based on the result of the comparison:

# %%
for p in patlist:
    print(p[3])
    print(f'\tage calculation: {2021 - p[1]}')
    print(f'\tage greater than 30?: {(2021 - p[1]) > 30}')
# Out:
# Edgar
# 	age calculation: 32
# 	age greater than 30?: True
# Dionna
# 	age calculation: 3
# 	age greater than 30?: False
# Eleni
# 	age calculation: 8
# 	age greater than 30?: False
# Ricardo
# 	age calculation: 10
# 	age greater than 30?: False
# Michelle
# 	age calculation: 52
# 	age greater than 30?: True

# %% [markdown]
# ### Elif - checking more than one condition <a name="elif"></a>
#
# Sometimes we'll want our code to pick among more than two actions depending on conditions. For example, maybe it's more useful to detect when people are in different decades of their lives than to just detect whether they are over or under a specific age.

# %%
for p in patlist:
    age = current_year - p[1]
    if age < 18:
        print(f"{p[3]} {p[4]} is a minor")
    elif age < 30:
        print(f"{p[3]} {p[4]} is in their twenties")
    elif age < 40:
        print(f"{p[3]} {p[4]} is in their thirties")
    else:
        print(f"{p[3]} {p[4]} is forty or over")
# Out:
# Edgar Hermann is in their thirties
# Dionna Heathcote is a minor
# Eleni Gusikowski is a minor
# Ricardo Mills is a minor
# Michelle Breitenberg is forty or over

# %% [markdown]
# ### And, or, not <a name="andornot"></a>
#
# We can use the logical operators **and**, **or**, and **not** in Python to create even more complex conditional expressions.
#
# For example, let's say we just want to find people who are in their thirties but we are not interested in listing out all the other possibilities.
# That is, we want people that are both older than 29 and younger than 40:

# %%
for p in patlist:
    age = current_year - p[1]
    if (age > 29) and (age < 40):
        print(f"{p[3]} {p[4]} is in their thirties")
# Out:
# Edgar Hermann is in their thirties

# %% [markdown]
# Here's an example that uses **or** to get people in two age categories:

# %%
for p in patlist:
    age = current_year - p[1]
    if (age < 18) or (age > 50):
        print(f"{p[3]} {p[4]} is in the middle at age {age}")
# Out:
# Dionna Heathcote is in the middle at age 8
# Eleni Gusikowski is in the middle at age 13
# Ricardo Mills is in the middle at age 15
# Michelle Breitenberg is in the middle at age 57

# %% [markdown]
# And here we use **not** just to exclude minors:

# %%
for p in patlist:
    age = current_year - p[1]
    if not(age < 18):
        print(f"{p[3]} {p[4]} is an adult")
# Out:
# Edgar Hermann is an adult
# Michelle Breitenberg is an adult

# %% [markdown]
# Note that checking **not(age < 18)** is really the same as checking **age >= 18**.

# %% [markdown]
# ---
#
# # In-class Exercise <a name="exercise"></a>
# ###
#
#
# ## Exercise
#
# Let's say we have some patient demographic data AND information about vaccination and COVID variant (we'll assume all these patients tested positive with one variant or another).
# Here's a data structure we could use to store that kind of data (we'll use better data structures later once we learn them):

# %%
# [0]: MRN, [1]: Birthdate, [2]: SSN, [3]: Fname, [4]: Lname, [5]: Zip, [6]: Vaccinated?, [7]: Variant
patlist2 = [[7182, 1989, '999-76-5071', 'Edgar', 'Hermann', 72034, True, 'Alpha'],
           [7491, 2018, '999-92-3312', 'Dionna', 'Heathcote', 72411, False, 'Delta'],
           [7052, 2013, '999-80-4418', 'Eleni', 'Gusikowski', 72736, False, 'Gamma'],
           [4851, 2011, '999-51-6410', 'Ricardo','Mills', 72046, True, 'Delta'],
           [1744, 1969, '999-72-5953', 'Michelle','Breitenberg', 72472, True, 'Alpha']]

# %% [markdown]
# Note that these are synthetic data -- they are not about real people. These data also might not really make sense in the real world (e.g. some "patients" in this example data are children and are marked as vaccinated).
#
# ### Task 1: Who is vaccinated? <a name="task1"></a>
#
# Write code that will loop through this list and uses an if statement to print out a message for each patient that is vaccinated. Here is example output:
#
# ```
# Edgar Hermann is vaccinated
# Ricardo Mills is vaccinated
# Michelle Breitenberg is vaccinated
# ```

# %%
# Task 1: print a message for each vaccinated patient
for p in patlist2:
    if p[6]==True : ## you can use p[6] without ==True
        print(f"{p[3]} {p[4]} is vaccinated")
# Out:
# Edgar Hermann is vaccinated
# Ricardo Mills is vaccinated
# Michelle Breitenberg is vaccinated

# %% [markdown]
# ### Task 2: Vaccinated or not (if/else) <a name="task2"></a>
#
# Write code that will loop through this list and uses an if/else statement to print out a message for each patient that says whether they are vaccinated. Here is example output:
#
# ```
# Edgar Hermann is vaccinated
# Dionna Heathcote is NOT vaccinated
# Eleni Gusikowski is NOT vaccinated
# Ricardo Mills is vaccinated
# Michelle Breitenberg is vaccinated
# ```

# %%
# Task 2: print vaccinated / NOT vaccinated for each patient
for p in patlist2:
    if p[6] == True:
        print(f"{p[3]} {p[4]} is vaccinated")
    else:
        print(f"{p[3]} {p[4]} is NOT vaccinated")
# Out:
# Edgar Hermann is vaccinated
# Dionna Heathcote is NOT vaccinated
# Eleni Gusikowski is NOT vaccinated
# Ricardo Mills is vaccinated
# Michelle Breitenberg is vaccinated
