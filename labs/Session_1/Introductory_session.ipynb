# %% [markdown]
# # BMIG 50303 Computational Methods for Biomedical Informatics

# %% [markdown]
# ---
# ## Session 1
#
# I would like to acknowledge the support from the ACCESS program through the NSF. In particular, the Cloudbank allocation from the University of California at Berkeley.

# %% [markdown]
# ## Table of Contents
# 1. [Python Introduction](#intro)
# 2. [Python Creator](#guido)
# 3. [Python Urban Myths](#myths)
# 4. [Python IDE (PyCharm)](#pycharm)
# 5. [Anaconda](#anaconda)

# %% [markdown]
# ## Python Introduction <a name="intro"></a>
#
# From wikipedia we can read that
#
# ![Wikipedia Entry](../../Figures/fig_python_wiki.png)

# %% [markdown]
# ## Python Creator <a name="guido"></a>
#
# Guido Van Rossum the creator of Python
#
# ![Wikipedia Entry](../../Figures/fig_guido_van_rossum.png)

# %% [markdown]
# ## Python Urban Myths <a name="myths"></a>
#
# + Python was named after the reptile. Nope, the name was inspired by a British show.
#
# ![Wikipedia Entry](../../Figures/fig_monty_python.png)
#
# + Python is going to be replaced soon by another computer program.
#
# More likely in the future, but as of today it is considered the *lingua franca* of data science.
#
# [Fun Statistics about Python](https://leftronic.com/blog/python-statistics/)

# %% [markdown]
# ## Python IDEs (PyCharm) <a name="pycharm"></a>
#
#
# Another program for python program [PyCharm](https://www.jetbrains.com/pycharm/) is a **integrated development environment (IDE)** .
#
# <img src="../../Figures/pycharm.png" width=600>
#
# Please use the **free version of PyCharm** that you can use to write your code. The professional trial is nice, but it will stop working very soon, and then you will need to install the free version anyway.

# %% [markdown]
# ## Python IDEs (VSCode) <a name="vscode"></a>
#
# One of the most versatiles IDEs is [VSCode](https://code.visualstudio.com/). This IDE is a powerhouse.
#
# <img src="../../Figures/fig_vscode.png" width=600>

# %% [markdown]
# ## Anaconda <a name="anaconda"></a>
#
# If you want to work with Python locally, there are several ways to do it.
#
# + You can go directly to the [Python](https://www.python.org/downloads/) website and download a recent version (preferably version 3.* )
#
# > **Please note that the versions 2 and 3 of python are not exactly compatible.**
#
# + You can also use [Anaconda](https://www.anaconda.com/).
#
# Anaconda is an open-source program that manages python *packages* (and also R, Ruby, etc.)
#
# <img src="../../Figures/anaconda.png" width=600>
#
# Anaconda contains tons of packages and it is quite big but simplifies installation. Also beginner programmers do not have to suffer from the *environment chaos* that can be build upon a python installation.
#
# ![](../../Figures/fig_python_degraded.png)
# *Marty Kades SDSC*

# %% [markdown]
# ## Jupyter vs IDE <a name="jupyter"></a>
#
# [Jupyter](https://jupyter.org/) notebooks are very good for interactive computing.
#
# <img src="../../Figures/jupyter.png" width=600>
#
# We will be using resources from jupyterhub from the Univesity of California at Berkeley

# %% [markdown]
# ---
# # Session 2
#
# Notes were developed in collaboration with Dr. Jonathan Bona

# %% [markdown]
# ## Table of Contents
# 1. [Variables in Python](#variables)
# 2. [Python keywords](#keywords)
# 3. [Strings](#strings)
# 4. [Basic Operations with Strings](#stringoperations)
# 5. [String Immutability](#stringsimmutability)
# 6. [String Methods](#stringmethods)
# 7. [Formated Strings](#fstrings)
# 8. [Comparing Strings](#comparingstrings)
# 9. [Numbers](#numbers)
# 10. [Number Comparison](#ncomparison)
# 11. [Operations with Numbers](#numbersoperations)
# 12. [Printing Numbers](#printnumbers)
# 13. [Numbers vs. Strings](#numbervsstring)
# 14. [References](#references)

# %% [markdown]
# ## Variables in Python <a name="variables"></a>
#
# A *variable* in python is a placeholder that will keep some sort of data structure (technically an **object**).

# %%
a=3.14
a+1
# Out:
# 4.140000000000001

# %% [markdown]
# In these two lines, several things are happening:
# + Python creates the variable *a* and assigns the value 5.0
# + Everytime the variable *a* is invoked, Python replaces the variable by its assigned value.
#
# > Type the following code

# %%
5=b
# Out:
#   Cell In[7], line 1
#     5=b
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Note that the computer needs to know that the variable exists before it usses it!

# %%
myvariable=3
2*myvariable
# Out:
# 6

# %%
b+1.0
b=2.0

# %% [markdown]
# Also, remember the conventions for naming variables. Valid variable names
# + Letters, numbers and underscores
# + Spaces are not allowed
# + Do not use Python **keywords** as variable names
# + Do not use **dots**
#
#
# Invalid names for variables include

# %%
a.1=5.0
a 1=5.0
print=4.0

# %% [markdown]
# ### Python Keywords <a name="keywords"></a>
#
# The following English words must not be used as variable name
#
# **and, as, break, class, continue, def, del, elif, else, except, exec, finally, for, from, global, if, import, in, is, lambda, not, or, pass, print, raise, return, try,
# while, with, yield**

# %% [markdown]
# ## Strings in Python <a name="strings"></a>
#
# *Strings* are sequences of alphanumeric characters. Some of these characters can be *invisible* (e.g., spaces, new-lines, etc.)
# They start and end with either a single quotation mark or double quotation mark.

# %%
my_string1='hi there'
my_string2="hello there"

# %% [markdown]
# We can access specific locations that are indexed
#
# > In Python, first elements of a string, list, etc. **start at the zeroth location**

# %%
print(my_string1[3])
# Out:
# t

# %%
print(my_string1[5])
# Out:
# e

# %% [markdown]
# We can also take **slices** or parts of a string

# %%
print(my_string2[3:])
# Out:
# lo there

# %% [markdown]
# Or going in the reverse order

# %%
print(my_string2[-2])
# Out:
# r

# %% [markdown]
# ### Operations with strings <a name="stringoperations"></a>
#
# One basic operation with strings is **concatenation**, which means pasting together two strings

# %%
print(my_string3)
# Out:
# hi there:hello there

# %%
my_string3=my_string1+ my_string2

# %% [markdown]
# Or we can add something else

# %%
my_string3=my_string1+":"+my_string2

# %% [markdown]
# We can also **repeat** concatenating strings

# %%
my_string4=3*my_string3

# %% [markdown]
# ### Immutability and Special characters<a name="stringsimmutability"></a>
#
# One may need to change the string

# %%
my_string1[1]="o"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 my_string1[1]="o"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# However, Python consider strings **immutable**, which means that the only way to change a string is to generate a new one with the given changes.

# %%
my_string5=my_string1[0]+"o"+my_string1[2:]

# %% [markdown]
# Internally, computers identify characters by assigning them a number (ASCII code)
#
#
# ![image](https://user-images.githubusercontent.com/20749994/125445591-ef65f296-0ee4-406c-bbca-c4491cf85719.png)
#
# source:wikipedia
#
# There are some commonly use characters
# + tab character represented by '\t'
# + new line character represented by '\n'
#
# So, we can add this lyrics

# %%
weeknd_lyrics="I said, ooh, I'm blinded by the lights\n " + \
"\nNo, \nI can't sleep until I feel your touch\n" + \
"\tI said, ooh, I'm drowning in the night\n" + \
"Oh, when I'm like this, you're the one I trust\n"

# %%
print(weeknd_lyrics)
# Out:
# I said, ooh, I'm blinded by the lights
#
# No,
# I can't sleep until I feel your touch
# 	I said, ooh, I'm drowning in the night
# Oh, when I'm like this, you're the one I trust

# %% [markdown]
# source: https://lyricsondemand.com/w/weekndlyrics/blindinglightslyrics.html
#
# > Python can use [unicode](https://en.wikipedia.org/wiki/List_of_Unicode_characters) characters that will go well beyond the ASCII range.

# %%
unexpected_truth="I'm awake in this class " +chr(189)+" of the time" +"\n"+ "the other " +chr(190)+ " I'm checking my instagram account"
print(unexpected_truth)
# Out:
# I'm awake in this class ½ of the time
# the other ¾ I'm checking my instagram account

# %% [markdown]
# ### String Methods <a name="stringmethods"></a>
#
# Methods are functions that perform operations with strings for us. We don't have to define those functions are already in the language

# %%
partial_lyric="  I said, ooh, I'm drowning in the night "
print(partial_lyric.upper())
print(partial_lyric.rstrip())
print(partial_lyric.lstrip())
print(partial_lyric.replace("I","i"))
print(partial_lyric.lower())
# Out:
#   I SAID, OOH, I'M DROWNING IN THE NIGHT
#   I said, ooh, I'm drowning in the night
# I said, ooh, I'm drowning in the night
#   i said, ooh, i'm drowning in the night
#   i said, ooh, i'm drowning in the night

# %% [markdown]
# ### Format strings (fstrings) <a name="fstrings"></a>
#
# This is a pythonistic replacement method

# %%
my_school="UAMS"
my_location="Little Rock"
where_am_I=f"{my_school} in {my_location}"
new_stuff=f"(my_school)"
print(my_school.capitalize())
print(f"{my_school} is in {my_location.upper()}")
print(new_stuff)
# Out:
# Uams
# UAMS is in LITTLE ROCK
# (my_school)

# %%
my_nameh="horacio"
print(my_nameh.capitalize())
# Out:
# Horacio

# %% [markdown]
# ### Comparison of Strings <a name="comparingstrings"></a>
#
# We can use the use *==* symbol or *!=* symbol to determine whether the strings are the same or not.
# This way of proceed is a bit crude

# %%
print('Lebron James'== 'LeBron James')
print(' Michael Jordan'== 'Michael Jordan')
# Out:
# False
# False

# %% [markdown]
# ## Numbers in Python <a name="numbers"></a>
#
# A quick recall of college algebra
#
# Integers are whole numbers: ...,-3,-2,-1,0,1,2,3,...
# A rational number is the ratio (quotient) of two integers p/q where q>0.
# A real number (floating point) is a quatity x=n+0.d1d2... where di's are digits between 0 and 9 (do not have infinite number of 9's)

# %%
a=3
b=4

# %% [markdown]
# We can use the basic arithmetic operations

# %%
a+1
a-2
# Out:
# 1

# %% [markdown]
# The division is a little bit odd, but let's see

# %%
print(a/2+b)
print(a//2 +b)
# Out:
# 5.5
# 5

# %% [markdown]
# There is a handy shortcut

# %%
c=20
c+=1 # This is the same as c=c+1

# %% [markdown]
# ### Number comparison <a name="ncomparison"></a>
#
# When we compare two numbers, say 3>2, we obtain a **logical value** (True or False)

# %%
3<4
# Out:
# True

# %% [markdown]
# Now, we can add some logic

# %%
3<4 and 8<9
# Out:
# True

# %% [markdown]
# Other logic comparisons are

# %%
1!=2 or 3>4
# Out:
# True

# %% [markdown]
# > Fun fact. In 1993, Sunsoft had a *priority one*  bug report that was holding up the sale of $20 million worth hardware.
# > The problem was the following line

# %%
x=2  # this was suppose to be the correct line
x==2 # but this was typed instead

# %% [markdown]
# ### Other basic operations <a name="numbersoperations"></a>
#
# Power function

# %%
a=2
a**4
# Out:
# 16

# %% [markdown]
# Sum of a sequnce of numbers (tuple)

# %%
sum((1,2,3,4,5,6))
# Out:
# 21

# %% [markdown]
# > Even larger computers cannot hold an infinite amount of numbers. So we have only an **approximation** of those numbers.

# %%
0.1+0.1+0.1-0.3
# Out:
# 5.551115123125783e-17

# %% [markdown]
# ### Printing Numbers <a name="printnumbers"></a>
#
# We can print numbers with specific format

# %%
my_pi=3.141592653589793
print("%.2f"%my_pi) ## The old way to have the number rounded 2 decimal places
print("{0:.2f}".format(my_pi)) ## The pythonistic way
print("%E" % my_pi)
# Out:
# 3.14
# 3.14
# 3.141593E+00

# %% [markdown]
# ### Numbers vs Strings <a name="numbervsstring"></a>
#
# Let's suppose you have the code

# %%
uams_zip="UAMS zip code is" + 72205
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 uams_zip="UAMS zip code is" + 72205
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# It sends an error, because **intergers(or floats) ARE NOT strings**
#
# You can solve this problem with the following code

# %%
uams_zip="UAMS zip code is " + str(72205)

# %% [markdown]
# > There is another function called _repr_ that produces something similar to _str_
# > It is not the same method, but we will discuss those later in the course.

# %%
uams_zip="UAMS zip code is " + repr(72205)
print(uams_zip)
# Out:
# UAMS zip code is 72205

# %% [markdown]
# Conversely, we can transform a string containing only numbers to its corresponding value.

# %%
a= int('75')+3
b=float('3e2')+0.9
c=float('7,399.05')+0.07 #this is a trouble line
print(a+b+c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 a= int('75')+3
#       2 b=float('3e2')+0.9
# ----> 3 c=float('7,399.05')+0.07 #this is a trouble line
#       4 print(a+b+c)
#
# ValueError: could not convert string to float: '7,399.05'

# %% [markdown]
# Correct the previous code so you can obtain the printed value.

# %% [markdown]
# ## References <a name="references"></a>
#
# 1. [Python Crashcourse](http://www.amazon.com/Python-Crash-Course-2nd-Edition/dp/1593279280/ref=sr_1_3?dchild=1&keywords=python+crash+course&qid=1626355851&sr=8-3) E. Matthes. Second Edition. No starch press (2019)
# 2. [Rapid GUI Programming with Python and Qt](http://www.amazon.com/Programming-Python-Prentice-Software-Development/dp/0132354187/ref=sr_1_3?crid=3HIAT02B1BFAT&dchild=1&keywords=rapid+gui+programming+with+python+and+qt&qid=1626355927&sprefix=rapid+gui+p%2Caps%2C184&sr=8-3) M. Summerfield. Prentice Hall. (2007)
# 3. [Learning Python](http://www.amazon.com/Learning-Python-5th-Mark-Lutz/dp/1449355730/ref=sr_1_3?dchild=1&keywords=learning+python+lutz&qid=1626356046&sr=8-3) M. Lutz. Fourth Edition. O'Reilly (2009)
